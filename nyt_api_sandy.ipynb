# %%
import requests
import json
import pandas as pd
from pprint import pprint
from config import nyt_key, token

# %% [markdown]
# # Data for Damages from Hurricane Sandy

# %%
data = pd.read_excel('./SBA_Disaster_Loan_Data_Superstorm_Sandy_0.xlsx',sheet_name=[3])
for k, v in data.items():
    starter_df = pd.DataFrame(v)

# %%
starter_df.columns = starter_df.iloc[1]
starter_df = starter_df.drop([0,1])

sorted_df = starter_df.reset_index(drop=True)
#sorted_df

# %%
nj_df = sorted_df.loc[sorted_df['Damaged Property State Code']=='NJ']
nj_df = nj_df.reset_index(drop=True)
#nj_df

# %%
final_nj_df = nj_df[['Damaged Property City Name','Damaged Property Zip Code','Damaged Property County/Parish Name',
                    'Total Verified Loss','Verified Loss Real Estate','Verified Loss Content','Total Approved Loan Amount',
                    'Approved Amount Real Estate','Approved Amount Content']]
final_nj_df
# Out:
# 1   Damaged Property City Name Damaged Property Zip Code  \
# 0                     ABERDEEN                     07747
# 1                      ABSECON                     08201
# 2                      ABSECON                     08205
# 3                 ALANTIC CITY                     08401
# 4                    ALLENDALE                     07401
# ..                         ...                       ...
# 965             WOODCLIFF LAKE                     07677
# 966              WOODLAND PARK                     07424
# 967                  WOODSTOWN                     08098
# 968                WRIGHTSTOWN                     08562
# 969                    WYCKOFF                     07481
#
# 1   Damaged Property County/Parish Name Total Verified Loss  \
# 0                              MONMOUTH               65852
# 1                              ATLANTIC              364029
# 2                              ATLANTIC               38740
# ...

# %%
data = pd.read_excel('./SBA_Disaster_Loan_Data_Superstorm_Sandy_0.xlsx',sheet_name=[4])
for k, v in data.items():
    starter_df = pd.DataFrame(v)

# %%
starter_df.columns = starter_df.iloc[1]
starter_df = starter_df.drop([0,1])

sorted_df = starter_df.reset_index(drop=True)
#sorted_df

# %%
nj_business_df = sorted_df.loc[sorted_df['Damaged Property State Code']=='NJ']
nj_business_df = nj_business_df.reset_index(drop=True)
#nj_business_df

# %%
final_nj_business_df = nj_business_df[['Damaged Property City Name','Damaged Property Zip Code',
                                      'Damaged Property County/Parish Name','Total Verified Loss',
                                      'Verified Loss Real Estate','Verified Loss Content','Total Approved Loan Amount',
                                      'Approved Amount Real Estate','Approved Amount Content','Approved Amount EIDL']]
final_nj_business_df
# Out:
# 1   Damaged Property City Name Damaged Property Zip Code  \
# 0                      BAYONNE                     07002
# 1                    CARLSTADT                     07072
# 2                   COLTS NECK                     07722
# 3                    ENGLEWOOD                     07631
# 4                     FORT LEE                     07024
# ..                         ...                       ...
# 735                  WOODRIDGE                     07075
# 736                WRIGHTSTOWN                     08562
# 737                    WYCKOFF                     07481
# 738                  YARDVILLE                     08620
# 739                SOUTH RIVER                     08882
#
# 1   Damaged Property County/Parish Name Total Verified Loss  \
# 0                                HUDSON                   0
# 1                                BERGEN                   0
# 2                                HUDSON                   0
# ...

# %% [markdown]
# # API call to NOAA

# %%
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:08721&startdate=2012-10-21&enddate=2012-11-02&limit=100"
response = requests.get(url,headers={'token':token})
data = response.json()
contents = data['results']
bayville_df = pd.DataFrame(contents)
bayville_df = bayville_df.loc[bayville_df['datatype']=='PRCP']
bayville_df['ZIP'] = '08721'
bayville_df
# Out:
#                    date datatype            station attributes  value    ZIP
# 0   2012-10-21T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# 2   2012-10-21T00:00:00     PRCP  GHCND:US1NJOC0042       ,,N,      0  08721
# 4   2012-10-22T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# 6   2012-10-22T00:00:00     PRCP  GHCND:US1NJOC0042       ,,N,      0  08721
# 8   2012-10-23T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# 10  2012-10-23T00:00:00     PRCP  GHCND:US1NJOC0042       ,,N,      0  08721
# 12  2012-10-24T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      5  08721
# 13  2012-10-24T00:00:00     PRCP  GHCND:US1NJOC0042       ,,N,      5  08721
# 14  2012-10-25T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# 16  2012-10-25T00:00:00     PRCP  GHCND:US1NJOC0042       ,,N,      0  08721
# 18  2012-10-26T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# ...

# %%
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:08204&startdate=2012-10-21&enddate=2012-11-02&limit=100"
response = requests.get(url,headers={'token':token})
data = response.json()
contents = data['results']
capemay_df = pd.DataFrame(contents)
capemay_df = capemay_df.loc[capemay_df['datatype']=='PRCP']
capemay_df['ZIP'] = '08204'
capemay_df
# Out:
#                    date datatype            station attributes  value    ZIP
# 0   2012-10-21T00:00:00     PRCP  GHCND:US1NJCM0002       ,,N,      0  08204
# 2   2012-10-21T00:00:00     PRCP  GHCND:USC00281351   ,,7,2400      0  08204
# 8   2012-10-22T00:00:00     PRCP  GHCND:US1NJCM0002       ,,N,      0  08204
# 10  2012-10-22T00:00:00     PRCP  GHCND:USC00281351   ,,7,2400      0  08204
# 16  2012-10-23T00:00:00     PRCP  GHCND:US1NJCM0002       ,,N,      0  08204
# 18  2012-10-23T00:00:00     PRCP  GHCND:USC00281351   ,,7,2400      0  08204
# 24  2012-10-24T00:00:00     PRCP  GHCND:US1NJCM0002       ,,N,      0  08204
# 26  2012-10-24T00:00:00     PRCP  GHCND:USC00281351   ,,7,2400      0  08204
# 32  2012-10-25T00:00:00     PRCP  GHCND:US1NJCM0002       ,,N,      0  08204
# 34  2012-10-25T00:00:00     PRCP  GHCND:USC00281351   ,,7,2400      0  08204
# 40  2012-10-26T00:00:00     PRCP  GHCND:US1NJCM0002       ,,N,      0  08204
# ...

# %%
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:08401&startdate=2012-10-21&enddate=2012-11-02&limit=100"
response = requests.get(url,headers={'token':token})
data = response.json()
contents = data['results']
AC_df = pd.DataFrame(contents)
AC_df = AC_df.loc[AC_df['datatype']=='PRCP']
AC_df['ZIP'] = '08401'
AC_df
# Out:
#                    date datatype            station attributes  value    ZIP
# 0   2012-10-21T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# 7   2012-10-22T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# 14  2012-10-23T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# 21  2012-10-24T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# 28  2012-10-25T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# 35  2012-10-26T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# 42  2012-10-27T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# 49  2012-10-28T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400    251  08401
# 56  2012-10-29T00:00:00     PRCP  GHCND:USW00013724   ,,Z,2400   1819  08401
# 63  2012-10-30T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400     64  08401
# 70  2012-10-31T00:00:00     PRCP  GHCND:USW00013724   ,,X,2400      0  08401
# ...

# %%
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:08735&startdate=2012-10-21&enddate=2012-11-02&limit=100"
response = requests.get(url,headers={'token':token})
data = response.json()
contents = data['results']
seaside_df = pd.DataFrame(contents)
seaside_df = seaside_df.loc[seaside_df['datatype']=='PRCP']
seaside_df['ZIP'] = '08735'
seaside_df
# Out:
#                    date datatype            station attributes  value    ZIP
# 0   2012-10-21T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,      0  08735
# 2   2012-10-22T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,      0  08735
# 4   2012-10-23T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,      0  08735
# 6   2012-10-25T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,      0  08735
# 8   2012-10-26T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,      0  08735
# 10  2012-10-27T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,      0  08735
# 12  2012-10-28T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,      0  08735
# 14  2012-10-29T00:00:00     PRCP  GHCND:US1NJOC0008       ,,N,    254  08735

# %%
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:07740&startdate=2012-10-21&enddate=2012-11-02&limit=100"
response = requests.get(url,headers={'token':token})
data = response.json()
contents = data['results']
longbranch_df = pd.DataFrame(contents)
longbranch_df = longbranch_df.loc[longbranch_df['datatype']=='PRCP']
longbranch_df['ZIP'] = '07740'
longbranch_df
# Out:
#                    date datatype            station attributes  value    ZIP
# 0   2012-10-21T00:00:00     PRCP  GHCND:US1NJMN0048       ,,N,      0  07740
# 2   2012-10-21T00:00:00     PRCP  GHCND:USC00284987   ,,7,0800      0  07740
# 6   2012-10-22T00:00:00     PRCP  GHCND:US1NJMN0048       ,,N,      0  07740
# 8   2012-10-22T00:00:00     PRCP  GHCND:USC00284987   ,,7,0800      0  07740
# 12  2012-10-23T00:00:00     PRCP  GHCND:US1NJMN0048       ,,N,      0  07740
# 14  2012-10-23T00:00:00     PRCP  GHCND:USC00284987   ,,7,0800      0  07740
# 18  2012-10-24T00:00:00     PRCP  GHCND:US1NJMN0048       ,,N,     10  07740
# 19  2012-10-24T00:00:00     PRCP  GHCND:USC00284987   ,,7,0800      3  07740
# 23  2012-10-25T00:00:00     PRCP  GHCND:US1NJMN0048       ,,N,      0  07740
# 25  2012-10-25T00:00:00     PRCP  GHCND:USC00284987   ,,7,0800      0  07740
# 29  2012-10-26T00:00:00     PRCP  GHCND:US1NJMN0048      T,,N,      0  07740
# ...

# %%
sandy_df = pd.concat([bayville_df,capemay_df,AC_df,seaside_df,longbranch_df])
sandy_df = sandy_df.reset_index(drop=True)
sandy_df
# Out:
#                    date datatype            station attributes  value    ZIP
# 0   2012-10-21T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# 1   2012-10-21T00:00:00     PRCP  GHCND:US1NJOC0042       ,,N,      0  08721
# 2   2012-10-22T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# 3   2012-10-22T00:00:00     PRCP  GHCND:US1NJOC0042       ,,N,      0  08721
# 4   2012-10-23T00:00:00     PRCP  GHCND:US1NJOC0024       ,,N,      0  08721
# ..                  ...      ...                ...        ...    ...    ...
# 91  2012-10-31T00:00:00     PRCP  GHCND:USC00284987  ,Z,7,0800      0  07740
# 92  2012-11-01T00:00:00     PRCP  GHCND:US1NJMN0048       ,,N,      3  07740
# 93  2012-11-01T00:00:00     PRCP  GHCND:USC00284987   ,,7,0800      0  07740
# 94  2012-11-02T00:00:00     PRCP  GHCND:US1NJMN0048       ,,N,      0  07740
# 95  2012-11-02T00:00:00     PRCP  GHCND:USC00284987   ,,7,0800      0  07740
#
# [96 rows x 6 columns]

# %% [markdown]
# # API Call to NYT

# %%
url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Hurricane Sandy&api-key={nyt_key}'
response = requests.get(url).json()

# %%
contents = response['response']['docs']
#pprint(contents)

# %%
news_list = []
for article in contents:
    news_dict={}
    news_dict['Headlines'] = (article['headline']['main'])
    news_dict['Contents'] = (article['lead_paragraph'])
    news_dict['Source'] = (article['source'])
    news_dict['Pub Date'] = (article['pub_date'])
    news_dict['URL:'] = (article['web_url'])
    news_list.append(news_dict)

# %%
news_df = pd.DataFrame(news_list)
news_df
# Out:
#                         Headlines  \
# 0  Hurricane Sandy’s Rising Costs
# 1       Hurricane Sandy in Queens
# 2       Hurricane Sandy Aftermath
# 3      Paying for Hurricane Sandy
# 4          Hurricane Sandy’s Path
# 5           Hurricane Sandy Haiku
# 6             Hurricane Sandy Aid
# 7       Nights of Hurricane Sandy
# 8    Hurricane Sandy and the Poor
# 9    Aftermath of Hurricane Sandy
#
#                                             Contents              Source  \
# 0  Gov. Andrew Cuomo’s latest request for federal...  The New York Times
# 1  Residents of Far Rockaway, Queens, embraced th...  The New York Times
# 2             Images from the weeks after the storm.  The New York Times
# 3  Victims of the storm rely on complicated gover...  The New York Times
# 4  Follow the path of the storm across the Northe...  The New York Times
# 5                                        Dear Diary:  The New York Times
# ...

# %%
url2 = f'https://api.nytimes.com/svc/archive/v1/2012/10.json?api-key={nyt_key}'
response2 = requests.get(url2).json()
content = response2['response']['docs']

# %%
content_df = pd.DataFrame(content)
#content_df.head()

# %%
narrow_content_df = content_df.loc[content_df['news_desk']=='New York']
narrow_content_df = narrow_content_df.loc[narrow_content_df['pub_date']>='2012-10-28T18:05:43+0000']

# %%
final_archive_df = narrow_content_df[['abstract','lead_paragraph','source','pub_date','web_url']]
final_archive_df = final_archive_df.rename(columns={'abstract':'Headlines','lead_paragraph':'Contents',
                                                    'source':'Source','pub_date':'Pub Date',
                                                    'web_url':'URL:'})
final_archive_df
# Out:
#                                               Headlines  \
# 7877  A 13-day chronicle of the devastating East Coa...
# 7887  There are three evacuation zones in New York C...
# 7985  Watching the storm from the 51st floor of the ...
# 8220  A brief photographic history of major storms i...
# 8274  Hurricane Sandy, a monstrous storm all but wit...
# 8290  More than six million customers lost power Mon...
# 8402  The damage and flooding from Hurricane Sandy i...
# 8453  Times readers submitted their photos of storm ...
# 8474  Hurricane Sandy knocked out power to hundreds ...
# 8501  The storm left a trail of deadly destruction, ...
# 8715  The restoration status in areas with significa...
#
#                                                Contents              Source  \
# 7877  A 13-day chronicle of the devastating East Coa...  The New York Times
# 7887  There are three evacuation zones in New York C...  The New York Times
# ...

# %% [markdown]
# # Merge News DataFrames

# %%
final_news_df = pd.concat([news_df,final_archive_df])
final_news_df = final_news_df.reset_index(drop=True)
final_news_df
# Out:
#                                             Headlines  \
# 0                      Hurricane Sandy’s Rising Costs
# 1                           Hurricane Sandy in Queens
# 2                           Hurricane Sandy Aftermath
# 3                          Paying for Hurricane Sandy
# 4                              Hurricane Sandy’s Path
# 5                               Hurricane Sandy Haiku
# 6                                 Hurricane Sandy Aid
# 7                           Nights of Hurricane Sandy
# 8                        Hurricane Sandy and the Poor
# 9                        Aftermath of Hurricane Sandy
# 10  A 13-day chronicle of the devastating East Coa...
# 11  There are three evacuation zones in New York C...
# 12  Watching the storm from the 51st floor of the ...
# 13  A brief photographic history of major storms i...
# 14  Hurricane Sandy, a monstrous storm all but wit...
# 15  More than six million customers lost power Mon...
# ...

# %% [markdown]
# # Send Data to MongoDB

# %%
import pymongo
import json
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)

# define database
db=client['hurricane_sandy_db']

# define collections
collection1=db['sandy_financial_impact']
collection2=db['sandy_weather_data']
collection3=db['sandy_related_headlines']

collection1.drop()
collection2.drop()
collection3.drop()

# send to mongodb
collection1.insert_many(final_nj_df.to_dict('records'))
collection1.insert_many(final_nj_business_df.to_dict('records'))
collection2.insert_many(sandy_df.to_dict('records'))
collection3.insert_many(news_df.to_dict('records'))

# %% [markdown]
# # Send to Cloud MongoDB

# %%
from config import cloudM ,cloudMpassword 
#print (cloudM,cloudMpassword)
cloudstr=f'mongodb+srv://{cloudM}:{cloudMpassword}@garrettgomez.rwyzw.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'
cloudclient = MongoClient(cloudstr)

collection1.drop()
collection2.drop()
collection3.drop()

# define database
db=cloudclient['hurricane_sandy_db']

# define collections
collection1=db['sandy_financial_impact']
collection2=db['sandy_weather_data']
collection3=db['sandy_related_headlines']

# send to cloud mongo
collection1.insert_many(final_nj_df.to_dict('records'))
collection1.insert_many(final_nj_business_df.to_dict('records'))
collection2.insert_many(sandy_df.to_dict('records'))
collection3.insert_many(news_df.to_dict('records'))
